# %%
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing('KRX')

# %%
symbol_name_df = df_krx[['Symbol','Name']].set_index('Name')

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23760/3425439879.py in <module>
# ----> 1 symbol_name_df.index['크래프톤']
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
dict_df = symbol_name_df.to_dict()
dict_df['Symbol']['삼성바이오로직스']
# Out:
# '207940'

# %%
dict_df['Symbol']['크래프톤']
# Out:
# '259960'

# %%
def get_close(name:str, date): 
    code = dict_df['Symbol'][name]
    df = fdr.DataReader(code , date)
    return df

# %%
samba = get_close('삼성바이오로직스', '2021')
woori = get_close('우리금융지주', '2021')
krafton = get_close('크래프톤', '2021')

# %%
usd_krw = fdr.DataReader('USD/KRW', '2021')

# %%
usd_krw['삼바'] = samba['Close']
usd_krw['우리'] = woori['Close']
usd_krw['크랩'] = krafton['Close']

# %%
df = usd_krw[['Close','삼바','우리','크랩']]

# %%
df = df.rename(columns={'Close':'KRW'})

# %%
daily_ret = df[['KRW','삼바','우리']].pct_change() #일간변동률
annual_ret = daily_ret.mean() * 252 #연간수익률
daily_cov = daily_ret.cov() #일간 리스크 = 일간 변동률의 공분산
annual_cov = daily_cov * 252 #연간 리스크 = 일간 공분산 * 연간일수


port_ret = []
port_risk = []
port_weights = []
sharpe_ratio = []

# %%
stocks = ['KRW','삼바','우리']

# %%
import numpy as np
import pandas as pd
for _ in range(20000):
    weights = np.random.random(len(stocks))
    weights /= np.sum(weights)
    
    returns = np.dot(weights, annual_ret)
    risk = np.sqrt(np.dot(weights.T, np.dot(annual_cov, weights)))
    
    port_ret.append(returns)
    port_risk.append(risk)
    port_weights.append(weights)
    sharpe_ratio.append(returns/risk)

portfolio = { 'Returns':port_ret, 'Risk':port_risk, 'Sharpe':sharpe_ratio}
for i,s in enumerate(stocks):
    portfolio[s] = [weight[i] for weight in port_weights ]
df = pd.DataFrame(portfolio)
df = df[['Returns','Risk','Sharpe'] + [s for s in stocks]]

# %%
max_sharpe = df.loc[df['Sharpe'] == df['Sharpe'].max()]
min_risk = df.loc[df['Risk'] == df['Risk'].min()]

# %%
min_risk
# Out:
#          Returns        Risk    Sharpe       KRW        삼바        우리
# 6964  706.004406  608.468707  1.160297  0.346977  0.012064  0.640959

# %%
import matplotlib as plt
df.plot.scatter(x='Risk',y='Returns', figsize=(10,7), grid=True)
plt.title('Efficient Frontier')
plt.xlable('Risk')
plt.ylable('Expected Returns')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23760/149501165.py in <module>
#       1 import matplotlib as plt
#       2 df.plot.scatter(x='Risk',y='Returns', figsize=(10,7), grid=True)
# ----> 3 plt.title('Efficient Frontier')
#       4 plt.xlable('Risk')
#       5 plt.ylable('Expected Returns')
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23760/3360122881.py in <module>
# ----> 1 usd_krw[['삼바'] + usd_krw['우리']]
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\arraylike.py in __radd__(self, other)
#      94     @unpack_zerodim_and_defer("__radd__")
#      95     def __radd__(self, other):
# ---> 96         return self._arith_method(other, roperator.radd)
#      97
#      98     @unpack_zerodim_and_defer("__sub__")
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    5524
#    5525         with np.errstate(all="ignore"):
# -> 5526             result = ops.arithmetic_op(lvalues, rvalues, op)
#    5527
#    5528         return self._construct_result(result, name=res_name)
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     222         _bool_arith_check(op, left, right)
#     223
# --> 224         res_values = _na_arithmetic_op(left, right, op)
#     225
#     226     return res_values
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#     168         if is_object_dtype(left) or is_object_dtype(right) and not is_cmp:
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     237         if use_numexpr:
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#     241
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     if _TEST_MODE:
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#      71
#
# c:\Users\dlfrn\stock\lib\site-packages\pandas\core\roperator.py in radd(left, right)
#       7
#       8 def radd(left, right):
# ----> 9     return right + left
#      10
#      11
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U2'), dtype('float64')) -> None
